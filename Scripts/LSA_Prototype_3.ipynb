# %%
import sklearn
# Import all of the scikit learn stuff
from __future__ import print_function
from sklearn.decomposition import TruncatedSVD
from sklearn.feature_extraction.text import TfidfVectorizer 
from sklearn.feature_extraction.text import CountVectorizer 
from sklearn.preprocessing import Normalizer
from sklearn import metrics
from sklearn.cluster import KMeans, MiniBatchKMeans
import pandas as pd
import warnings
# Suppress warnings from pandas library warnings.filterwarnings("ignore", category=DeprecationWarning,
import numpy as np
import os
import languageProcess as lp

# %%
articles=[]
path='../RandomBaseline/plaindata'
categories=os.listdir(path)
categories=[cat for cat in categories if os.path.exists(path+"/"+cat+"/AA/wiki_00")]
for cat in categories:
    filepath = path+"/"+cat+"/AA/wiki_00"
    if os.path.exists(filepath):               #Save all base articles in an array of arrays
        articles += [lp.languageProcess(filepath).getWords()]

# %%
corpus = [' '.join(block) for block in articles]

# %%
vectorizer= TfidfVectorizer(use_idf=True)
dtm = vectorizer.fit_transform(corpus)
pd.DataFrame(dtm.toarray(),index=categories,columns=vectorizer.get_feature_names ()).head(10)
# Out:
#                   aba  abalone   abandon  abandonment  abasement     abbas  \
# Culture_20        0.0      0.0  0.000000     0.009972   0.000000  0.006159
# Nature_20         0.0      0.0  0.000000     0.001538   0.000000  0.000000
# Concepts_20       0.0      0.0  0.000000     0.000000   0.000000  0.000000
# History_20        0.0      0.0  0.007276     0.000000   0.007276  0.000000
# Technology_20     0.0      0.0  0.000000     0.000000   0.000000  0.000000
# Arts_20           0.0      0.0  0.000000     0.000000   0.000000  0.000000
# Entertainment_20  0.0      0.0  0.000000     0.000000   0.000000  0.000000
# Business_20       0.0      0.0  0.000000     0.000000   0.000000  0.000000
# Society_20        0.0      0.0  0.000000     0.000000   0.000000  0.000000
# Life_20           0.0      0.0  0.000000     0.000000   0.000000  0.000000
#
#                   abbess  abbreviation  abduction  aberrant    ...     \
# Culture_20           0.0      0.004986        0.0  0.005473    ...
# Nature_20            0.0      0.000000        0.0  0.000000    ...
# Concepts_20          0.0      0.000000        0.0  0.000000    ...
# History_20           0.0      0.000000        0.0  0.000000    ...
# Technology_20        0.0      0.000000        0.0  0.000000    ...
# Arts_20              0.0      0.000000        0.0  0.000000    ...
# Entertainment_20     0.0      0.000000        0.0  0.000000    ...
# Business_20          0.0      0.000000        0.0  0.000000    ...
# Society_20           0.0      0.000000        0.0  0.000000    ...
# Life_20              0.0      0.000000        0.0  0.000000    ...
#
#                         ਸਤ        ਸਦ       ਸਬਦ        ਸਮ        ਹਰ     さぁイコー  \
# Culture_20        0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# Nature_20         0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# Concepts_20       0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# History_20        0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# Technology_20     0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# Arts_20           0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# Entertainment_20  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# Business_20       0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# Society_20        0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# Life_20           0.006407  0.006407  0.006407  0.006407  0.006407  0.006407
#
#                      たまごっち       三尸饭      房中之术        素女
# Culture_20        0.000000  0.000000  0.000000  0.000000
# Nature_20         0.000000  0.000000  0.000000  0.000000
# Concepts_20       0.000000  0.000000  0.000000  0.000000
# History_20        0.000000  0.000000  0.000000  0.000000
# Technology_20     0.000000  0.000000  0.000000  0.000000
# Arts_20           0.000000  0.000000  0.000000  0.000000
# Entertainment_20  0.000000  0.000000  0.000000  0.000000
# Business_20       0.000000  0.000000  0.000000  0.000000
# Society_20        0.000000  0.000000  0.000000  0.000000
# Life_20           0.006407  0.006407  0.006407  0.006407
#
# [10 rows x 9833 columns]

# %%
# Get words that correspond to each column
vectorizer.get_feature_names()
# Out:
# ['aba',
#  'abalone',
#  'abandon',
#  'abandonment',
#  'abasement',
#  'abbas',
#  'abbess',
#  'abbreviation',
#  'abduction',
#  'aberrant',
#  'aberration',
#  'abhorrence',
#  'ability',
#  'ablation',
#  'abnormality',
#  'aboard',
#  'abode',
#  'abolition',
#  'abort',
#  'abortifacient',
#  'abortion',
#  'above',
#  'aboveground',
#  'abruption',
#  'absence',
#  'absent',
#  'absentee',
#  'absolute',
#  'absolution',
#  'absolutism',
#  'absolutist',
#  'absorption',
#  'abstainer',
#  'abstention',
#  'abstract',
#  'abstraction',
#  'abstractionism',
#  'absurd',
#  'absurdity',
#  'abu',
#  'abundance',
#  'abundant',
#  'abuse',
#  'aby',
#  'academic',
#  'academy',
#  'accelerate',
#  'acceleration',
#  'accelerator',
#  'accent',
#  'accentuate',
#  'accept',
#  'acceptance',
#  'acceptation',
#  'access',
#  'accessibility',
#  'accession',
#  'accessory',
#  'accident',
#  'accidental',
#  'acclamation',
#  'acclimatization',
#  'accommodate',
#  'accommodation',
#  'accompaniment',
#  'accomplice',
#  'accomplishment',
#  'accordance',
#  'accordion',
#  'account',
#  'accountability',
#  'accountant',
#  'accounting',
#  'accreditation',
#  'accretion',
#  'accumulate',
#  'accumulation',
#  'accuracy',
#  'accurate',
#  'accusation',
#  'accused',
#  'accuser',
#  'ace',
#  'acetone',
#  'acetylation',
#  'achieve',
#  'achievement',
#  'achiever',
#  'acid',
#  'acidification',
#  'acidity',
#  'acknowledged',
#  'acme',
#  'acoustic',
#  'acquaintance',
#  'acquisition',
#  'acre',
#  'acronym',
#  'acropolis',
#  'acrylic',
#  'act',
#  'action',
#  'activate',
#  'activation',
#  'activator',
#  'activism',
#  'activist',
#  'activity',
#  'actor',
#  'actress',
#  'actuality',
#  'acute',
#  'adage',
#  'adapt',
#  'adaptation',
#  'add',
#  'addict',
#  'addiction',
#  'addition',
#  'address',
#  'adduct',
#  'adequate',
#  'adherence',
#  'adherent',
#  'adhesion',
#  'adiposity',
#  'adjective',
#  'adjunct',
#  'adjust',
#  'adjustment',
#  'administer',
#  'administration',
#  'administrator',
#  'admiration',
#  'admirer',
#  'admissibility',
#  'admission',
#  'admit',
#  'admittance',
#  'admixture',
#  'adolescence',
#  'adolescent',
#  'adopt',
#  'adoptee',
#  'adopter',
#  'adoption',
#  'adoration',
#  'adornment',
#  'adsorption',
#  'adult',
#  'adulthood',
#  'advance',
#  'advancement',
#  'advantage',
#  'adventure',
#  'adventurer',
#  'adverb',
#  'adversary',
#  'advertise',
#  'advertisement',
#  'advertiser',
#  'advertising',
#  'advice',
#  'advise',
#  'adviser',
#  'advisor',
#  'advocacy',
#  'advocate',
#  'aeration',
#  'aero',
#  'aeronautics',
#  'aerosol',
#  'aesthetic',
#  'affability',
#  'affair',
#  'affect',
#  'affection',
#  'affiliate',
#  'affiliation',
#  'affinity',
#  'affliction',
#  'affluence',
#  'afford',
#  'afire',
#  'afraid',
#  'afterlife',
#  'aftermath',
#  'afternoon',
#  'afterschool',
#  'afterward',
#  'afterwards',
#  'age',
#  'agencies',
#  'agency',
#  'agenda',
#  'agent',
#  'aggregate',
#  'aggregation',
#  'aggregator',
#  'aggression',
#  'aggressiveness',
#  'agility',
#  'agitation',
#  'agitator',
#  'agnostic',
#  'agouti',
#  'agrarianism',
#  'agree',
#  'agreement',
#  'agriculturalist',
#  'agriculture',
#  'agronomist',
#  'agronomy',
#  'agua',
#  'aid',
#  'aide',
#  'ailment',
#  'aim',
#  'air',
#  'aircraft',
#  'aire',
#  'airman',
#  'airplane',
#  'airport',
#  'airway',
#  'aka',
#  'ala',
#  'alan',
#  'alarm',
#  'albedo',
#  'albeit',
#  'album',
#  'alchemist',
#  'alchemy',
#  'alcohol',
#  'alcoholism',
#  'alef',
#  'aleph',
#  'alert',
#  'alfalfa',
#  'algae',
#  'algebra',
#  'algorithm',
#  'alias',
#  'alidade',
#  'alien',
#  'alienation',
#  'align',
#  'alignment',
#  'alkali',
#  'alkaline',
#  'alkalinity',
#  'all',
#  'allan',
#  'allegation',
#  'allegiance',
#  'allegorical',
#  'allegory',
#  'allegro',
#  'aller',
#  'alleviate',
#  'alley',
#  'alliance',
#  'alligator',
#  'allocation',
#  'allotment',
#  'allow',
#  'allowance',
#  'alloy',
#  'allusion',
#  'ally',
#  'almanac',
#  'almond',
#  'alms',
#  'alongside',
#  'alpha',
#  'alphabet',
#  'alpine',
#  'also',
#  'altar',
#  'altazimuth',
#  'alter',
#  'alteration',
#  'alterity',
#  'alternate',
#  'alternation',
#  'alternative',
#  'altitude',
#  'altruism',
#  'alumina',
#  'aluminium',
#  'aluminosilicate',
#  'aluminum',
#  'alumna',
#  'amalgamation',
#  'amateur',
#  'ambassador',
#  'ambience',
#  'ambiguity',
#  'ambition',
#  'ambrosia',
#  'ambulance',
#  'amendment',
#  'amenity',
#  'ami',
#  'amidst',
#  'amin',
#  'amino',
#  'ammonia',
#  'ammonium',
#  'ammunition',
#  'amongst',
#  'amount',
#  'amour',
#  'amphibian',
#  'amphibole',
#  'amplification',
#  'amplifier',
#  'amplify',
#  'amplitude',
#  'amputee',
#  'amrita',
#  'amulet',
#  'amusement',
#  'an',
#  'analgesic',
#  'analogue',
#  'analogy',
#  'analyse',
#  'analyser',
#  'analysis',
#  'analyst',
#  'analytics',
#  'analyze',
#  'analyzer',
#  'anarchism',
#  'anarchosyndicalism',
#  'anarchy',
#  'anatomist',
#  'anatomy',
#  'ancestor',
#  'ancestry',
#  'anchor',
#  'anchorage',
#  'anchorite',
#  'ancient',
#  'and',
#  'android',
#  'anecdote',
#  'anesthesia',
#  'angel',
#  'anger',
#  'angle',
#  'angler',
#  'angstrom',
#  'angular',
#  'animal',
#  'animate',
#  'animation',
#  'anime',
#  'animism',
#  'animosity',
#  'anion',
#  'anisotropy',
#  'ankle',
#  'ann',
#  'anna',
#  'annals',
#  'annelid',
#  'annex',
#  'annexation',
#  'annihilate',
#  'annihilation',
#  'anniversary',
#  'annotation',
#  'announcement',
#  'announcer',
#  'annuity',
#  'anomaly',
#  'answer',
#  'ant',
#  'antarctica',
#  'ante',
#  'antecedent',
#  'antenna',
#  'anthology',
#  'anthropocentrism',
#  'anthropogenic',
#  'anthropologist',
#  'anthropology',
#  'anti',
#  'anticapitalism',
#  'anticapitalist',
#  'anticipate',
#  'anticipation',
#  'anticipatory',
#  'anticlericalism',
#  'anticommunist',
#  'anticonscription',
#  'antidrug',
#  'antigovernment',
#  'antilepton',
#  'antimilitarism',
#  'antioxidant',
#  'antiparticle',
#  'antipoverty',
#  'antiquark',
#  'antique',
#  'antiquity',
#  'antirealism',
#  'antisocialist',
#  'antitank',
#  'antithesis',
#  'antonym',
#  'anuran',
#  'anxiety',
#  'anybody',
#  'anyhow',
#  'anyone',
#  'anything',
#  'apa',
#  'apache',
#  'apart',
#  'apartheid',
#  'apartment',
#  'ape',
#  'apeiron',
#  'aphelion',
#  'aphorism',
#  'apocryphal',
#  'apologetics',
#  'apology',
#  'apomixis',
#  'apostle',
#  'apparatus',
#  'apparel',
#  'apparent',
#  'appeal',
#  'appearance',
#  'appears',
#  'appease',
#  'appendix',
#  'appetite',
#  'applause',
#  'apple',
#  'appliance',
#  'applicability',
#  'applicant',
#  'application',
#  'apply',
#  'appoint',
#  'appointment',
#  'appraisal',
#  'appreciate',
#  'appreciation',
#  'apprehension',
#  'apprentice',
#  'apprenticeship',
#  'approach',
#  'appropriate',
#  'appropriation',
#  'approval',
#  'approximate',
#  'approximation',
#  'april',
#  'apriority',
#  'apropos',
#  'aptitude',
#  'aptness',
#  'aqua',
#  'aquifer',
#  'arbiter',
#  'arbitrariness',
#  'arbitration',
#  'arbor',
#  'arboretum',
#  'arc',
#  'arcade',
#  'arcanum',
#  'arch',
#  'archaeological',
#  'archaeologist',
#  'archaeology',
#  'archbishop',
#  'archdeacon',
#  'archduke',
#  'archer',
#  'archery',
#  'archetype',
#  'architect',
#  'architecture',
#  'archival',
#  'archive',
#  'archon',
#  'are',
#  'area',
#  'areal',
#  'arena',
#  'argentine',
#  'argot',
#  'argue',
#  'argument',
#  'argumentation',
#  'ariel',
#  'arise',
#  'arisen',
#  'aristocracy',
#  'aristocrat',
#  'arm',
#  'armada',
#  'armor',
#  'army',
#  'arna',
#  'arrange',
#  'arrangement',
#  'array',
#  'arrest',
#  'arrival',
#  'arrogance',
#  'arrow',
#  'arroyo',
#  'arsenide',
#  'arsine',
#  'art',
#  'artefact',
#  'artery',
#  'arthropod',
#  'article',
#  'articulation',
#  'articulator',
#  'artifact',
#  'artifice',
#  'artificer',
#  'artillery',
#  'artisan',
#  'artist',
#  'as',
#  'asbestos',
#  'ascend',
#  'ascension',
#  'ascent',
#  'ascetic',
#  'asceticism',
#  'ash',
#  'ashur',
#  'aside',
#  'ask',
#  'asker',
#  'aspect',
#  'asphalt',
#  'asphyxiation',
#  'aspiration',
#  'aspire',
#  'aspirin',
#  'ass',
#  'assailant',
#  'assassin',
#  'assassination',
#  'assault',
#  'assemblage',
#  'assembly',
#  'assent',
#  'assert',
#  'assertion',
#  'assessment',
#  'asset',
#  'assign',
#  'assignment',
#  'assimilation',
#  'assist',
#  'assistance',
#  'assistant',
#  'associate',
#  'association',
#  'assonance',
#  'assuage',
#  'assume',
#  'assumption',
#  'assumptions',
#  'assurance',
#  'assure',
#  'asteroid',
#  'asthma',
#  'astonishment',
#  'astrodome',
#  'astrology',
#  'astronaut',
#  'astronomer',
#  'astronomy',
#  'astrophysicist',
#  'astrophysics',
#  'asylum',
#  'asymmetry',
#  'at',
#  'ate',
#  'atheism',
#  'atheist',
#  'athlete',
#  'athletics',
#  'atlas',
#  'atmosphere',
#  'atom',
#  'atomism',
#  'atrocity',
#  'attache',
#  'attachment',
#  'attack',
#  'attacker',
#  'attain',
#  'attainment',
#  'attempt',
#  'attend',
#  'attendance',
#  'attendant',
#  'attention',
#  'attenuate',
#  'attenuation',
#  'attestation',
#  'attitude',
#  'attorney',
#  'attract',
#  'attraction',
#  'attractiveness',
#  'attribute',
#  'attribution',
#  'attrition',
#  'auction',
#  'auctioneer',
#  'audience',
#  'audio',
#  'audiology',
#  'audition',
#  'auditory',
#  'augury',
#  'august',
#  'aura',
#  'auspex',
#  'authenticity',
#  'author',
#  'authoritarian',
#  'authoritarianism',
#  'authoritative',
#  'authority',
#  'authorization',
#  'authorship',
#  'autism',
#  'auto',
#  'autoantibody',
#  'autobiography',
#  'autogram',
#  'autoimmunity',
#  'automaton',
#  'automobile',
#  'autonomy',
#  'autopsy',
#  'autumn',
#  'availability',
#  'avalanche',
#  'avenue',
#  'average',
#  'aversion',
#  'aviation',
#  'avoid',
#  'avoidance',
#  'awakening',
#  'award',
#  'aware',
#  'awareness',
#  'awe',
#  'awoke',
#  'axiology',
#  'axiom',
#  'axion',
#  'axis',
#  'axle',
#  'ayatollah',
#  'azimuth',
#  'azure',
#  'azurine',
#  'babe',
#  'baboon',
#  'baby',
#  'bach',
#  'bachelor',
#  'back',
#  'backbone',
#  'backdrop',
#  'backer',
#  'backfill',
#  'background',
#  'backing',
#  'backlash',
#  'backup',
#  'backwards',
#  'backwater',
#  'bacon',
#  'bacteria',
#  'bacteriology',
#  'baculus',
#  'badge',
#  'bag',
#  'baggage',
#  'bagpiper',
#  'bah',
#  'bailiff',
#  'bailiwick',
#  'bain',
#  'baker',
#  'balance',
#  'ball',
#  'balloon',
#  'ballot',
#  'balloting',
#  'ballroom',
#  'balsam',
#  'bamboo',
#  'ban',
#  'band',
#  'banda',
#  'banding',
#  'bando',
#  'bang',
#  'bank',
#  'banker',
#  'banking',
#  'bankruptcy',
#  'banner',
#  'banquet',
#  'banyan',
#  'bap',
#  'baptism',
#  'bar',
#  'barbarian',
#  'barbaric',
#  'barber',
#  'barbera',
#  'barcelona',
#  'bare',
#  'bargain',
#  'bark',
#  'barker',
#  'barley',
#  'barnard',
#  'barometer',
#  'baron',
#  'baroque',
#  'barrack',
#  'barracuda',
#  'barrel',
#  'barren',
#  'barrier',
#  'barrio',
#  'barrister',
#  'barrow',
#  'barry',
#  'barter',
#  'barth',
#  'base',
#  'baseball',
#  'basement',
#  'basic',
#  'basil',
#  'basin',
#  'basis',
#  'basket',
#  'basketball',
#  'basque',
#  'bass',
#  'basso',
#  'bastion',
#  'bat',
#  'batch',
#  'bath',
#  'bathos',
#  'bathroom',
#  'batman',
#  'baton',
#  'battalion',
#  'battery',
#  'battle',
#  'battleground',
#  'bauxite',
#  'baxter',
#  'bay',
#  'beach',
#  'beam',
#  'beanstalk',
#  'bear',
#  'beard',
#  'bearer',
#  'bearing',
#  'beast',
#  'beat',
#  'beautiful',
#  'beauty',
#  'become',
#  'becomes',
#  'bed',
#  'bedrock',
#  'bedroom',
#  'bee',
#  'beef',
#  'beer',
#  'beetle',
#  'befall',
#  'beforehand',
#  'beggar',
#  'begin',
#  'beginning',
#  'behalf',
#  'behavior',
#  'behaviorism',
#  'behaviour',
#  'beholder',
#  'being',
#  'bel',
#  'belief',
#  'believability',
#  'believer',
#  'bell',
#  'belle',
#  'belong',
#  'belonging',
#  'belt',
#  'ben',
#  'bench',
#  'bend',
#  'beneath',
#  'benedict',
#  'benefactor',
#  'beneficiary',
#  'benefit',
#  'benevolence',
#  'benjamin',
#  'bennet',
#  'bent',
#  'bentonite',
#  'bereavement',
#  'beret',
#  'berlin',
#  'berry',
#  'berth',
#  'bertram',
#  'besides',
#  'bestiality',
#  'bestow',
#  'bet',
#  'beta',
#  'betaine',
#  'beth',
#  'betterment',
#  'betty',
#  'between',
#  'bevel',
#  'beverage',
#  'bey',
#  'bias',
#  'bibliography',
#  'bicameralism',
#  'bicarbonate',
#  'bicycle',
#  'bid',
#  'bidding',
#  'bien',
#  'bifurcation',
#  'bigamist',
#  'bigamy',
#  'bike',
#  'bilingual',
#  'bilingualism',
#  'bill',
#  'billboard',
#  'billing',
#  'billion',
#  'billionaire',
#  'bin',
#  'binary',
#  'bind',
#  'binder',
#  'binding',
#  'biochemist',
#  'biochemistry',
#  'biogeography',
#  'biography',
#  'biologist',
#  'biology',
#  'biome',
#  'biomechanics',
#  'biophysical',
#  'biosphere',
#  'biota',
#  'bipartisanship',
#  'bipolar',
#  'birch',
#  'bird',
#  'birth',
#  'birthday',
#  'birthplace',
#  'bishop',
#  'bison',
#  'bit',
#  'bitch',
#  'bite',
#  'bittersweet',
#  'bitty',
#  'bitwise',
#  'bivoltine',
#  'biweekly',
#  'black',
#  'blackboard',
#  'blacker',
#  'blackmail',
#  'bladder',
#  'blade',
#  'blair',
#  'blake',
#  'blame',
#  'blanc',
#  'blank',
#  'blanket',
#  'blasphemer',
#  'blasphemy',
#  'blast',
#  'blazer',
#  'bleacher',
#  'blend',
#  'blessing',
#  'blind',
#  'blindness',
#  'blister',
#  'blizzard',
#  'bloc',
#  'block',
#  'blockade',
#  'blocker',
#  'bloke',
#  'blonde',
#  'blondine',
#  'blood',
#  'bloodline',
#  'bloom',
#  'bloomer',
#  'blow',
#  'blowing',
#  'blown',
#  'blubber',
#  'bludgeon',
#  'blue',
#  'bluebird',
#  'blueprint',
#  'blush',
#  'boar',
#  'board',
#  'boarding',
#  'boast',
#  'boat',
#  'bob',
#  'boba',
#  'bobby',
#  'bock',
#  'bod',
#  'bodhi',
#  'body',
#  'bodybuilder',
#  'bog',
#  'bogart',
#  'bogus',
#  'boil',
#  'boiler',
#  'bola',
#  'boldness',
#  'bolivia',
#  'bolster',
#  'bomb',
#  'bombardier',
#  'bombardment',
#  'bomber',
#  'bon',
#  'bond',
#  'bondage',
#  'bonding',
#  'bone',
#  'bonsai',
#  'bonus',
#  'book',
#  'booklet',
#  'bookmark',
#  'bookshelf',
#  'bookshop',
#  'boom',
#  'boomer',
#  'boon',
#  'boost',
#  'booster',
#  'booth',
#  'border',
#  'bore',
#  'born',
#  'boron',
#  'borough',
#  ...]

# %%
# Fit LSA. Use algorithm = “randomized” for large datasets
#lsa = TruncatedSVD(99, algorithm = 'arpack')
lsa = TruncatedSVD(n_components=27,algorithm='arpack')
dtm_lsa = lsa.fit_transform(dtm.asfptype())
dtm_lsa = Normalizer(copy=False).fit_transform(dtm_lsa)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-d0913e899580> in <module>()
#       2 #lsa = TruncatedSVD(99, algorithm = 'arpack')
#       3 lsa = TruncatedSVD(n_components=27,algorithm='arpack')
# ----> 4 dtm_lsa = lsa.fit_transform(dtm.asfptype())
#       5 dtm_lsa = Normalizer(copy=False).fit_transform(dtm_lsa)
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/decomposition/truncated_svd.py in fit_transform(self, X, y)
#     162
#     163         if self.algorithm == "arpack":
# --> 164             U, Sigma, VT = svds(X, k=self.n_components, tol=self.tol)
#     165             # svds doesn't abide by scipy.linalg.svd/randomized_svd
#     166             # conventions, so reverse its outputs.
#
# ~/anaconda3/lib/python3.6/site-packages/scipy/sparse/linalg/eigen/arpack/arpack.py in svds(A, k, ncv, tol, which, v0, maxiter, return_singular_vectors)
#    1768
#    1769     if k <= 0 or k >= min(n, m):
# -> 1770         raise ValueError("k must be between 1 and min(A.shape), k=%d" % k)
#    1771
#    1772     if isinstance(A, LinearOperator):
#
# ValueError: k must be between 1 and min(A.shape), k=27

# %%
pd.DataFrame(lsa.components_,index = ["component_1","component_2"],columns = vectorizer.get_feature_names())

# %%
pd.DataFrame(dtm_lsa, index = categories, columns = ["component_1","component_2" ])

# %%
xs = [w[0] for w in dtm_lsa]
ys = [w[1] for w in dtm_lsa]
xs, ys

# %%
# Plot scatter plot of points %pylab inline
import matplotlib.pyplot as plt
plt.figure()
plt.scatter(xs,ys)
plt.xlabel('First principal component')
plt.ylabel('Second principal component')
plt.title('Plot of points against LSA principal components')
 
plt.show()

# %%
# Plot scatter plot of points with vectors %pylab inline
import matplotlib.pyplot as plt
plt.figure()
ax = plt.gca()
ax.quiver(0,0,xs,ys,angles='xy',scale_units='xy',scale=1, linewidth = .01)
ax.set_xlim([-1,1])
ax.set_ylim([-1,1])
plt.xlabel('First principal component')
plt.ylabel('Second principal component')
plt.title('Plot of points against LSA principal components')
plt.draw()
plt.show()

# %%
# Compute document similarity using LSA components
similarity = np.asarray(np.asmatrix(dtm_lsa) * np.asmatrix(dtm_lsa).T)
pd.DataFrame(similarity,index=categories, columns=categories)

# %%
similarity = np.asarray(np.asmatrix(dtm_lsa) * np.asmatrix(dtm_lsa).T)
pd.DataFrame(similarity,index=categories, columns=categories)
